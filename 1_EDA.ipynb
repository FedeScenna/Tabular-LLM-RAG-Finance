# %%
import pandas as pd
import sqlite3
import plotly.express as px
from tqdm import tqdm
import matplotlib.pyplot as plt
conn = sqlite3.connect("data/database.db")

# %%
df = pd.read_sql_query("SELECT * FROM price_data", conn)

# %%
max_date = df["date"].max()
df = df[df["date"]==max_date]

# %%
df = df[df["sharpe_ratio"]>=1]

# %%
df = df.sort_values(by='sharpe_ratio', ascending=False).head(100)

# Create Bubble Plot
plt.figure(figsize=(10, 6))  # Set figure size
# Sort stocks by Sharpe Ratio in descending order

# Plot
plt.figure(figsize=(12, 50))  # Adjust figure size for better readability
plt.barh(df['ticker'], df['sharpe_ratio'], color='skyblue', edgecolor='black')

# Add titles and labels
plt.title('Sharpe Ratios of 500 Stocks', fontsize=16)
plt.xlabel('Sharpe Ratio', fontsize=14)
plt.ylabel('Stock', fontsize=14)

# Adjust layout for better readability
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
